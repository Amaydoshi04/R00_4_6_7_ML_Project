# %%
import sympy as sp

# Define symbols
s, t = sp.symbols('s t')

# Define system parameters
m = 2  # Mass (kg)
b = 0.5  # Damping coefficient (Ns/m)
k = 4  # Spring constant (N/m)
F = 4 / (s**2 + 4**2)  # Laplace transform of external force F(t)

# Laplace transform of the equation of motion
X = sp.Function('X')(s)
eqn = m * s**2 * X + b * s * X + k * X - F

# Solve for X(s)
X_s = sp.solve(eqn, X)[0]

# %%
# Inverse Laplace transform to find displacement x(t) in time domain
x_t = sp.inverse_laplace_transform(X_s, s, t)
x_t_simplified = sp.simplify(x_t)

# Display the displacement expression
print("Displacement (in meters) as a function of time:")
print(x_t_simplified)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\polys\polyutils.py:211, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     209         base, exp = decompose_power_rat(factor)
# --> 211     monom[indices[base]] = exp
#     212 except KeyError:
#
# KeyError: RisingFactorial(_t + 1, 1.0)
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\polys\partfrac.py:81, in apart(f, x, full, **options)
#      80 try:
# ---> 81     (P, Q), opt = parallel_poly_from_expr((P, Q), x, **options)
#      82 except PolynomialError as msg:
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\polys\polytools.py:4411, in parallel_poly_from_expr(exprs, *gens, **args)
#    4410 opt = options.build_options(gens, args)
# -> 4411 return _parallel_poly_from_expr(exprs, opt)
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\polys\polytools.py:4462, in _parallel_poly_from_expr(exprs, opt)
#    4460         exprs[i] = exprs[i].as_expr()
# -> 4462 reps, opt = _parallel_dict_from_expr(exprs, opt)
#    4463 if not opt.gens:
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\polys\polyutils.py:332, in _parallel_dict_from_expr(exprs, opt)
#     331 if opt.gens:
# --> 332     reps, gens = _parallel_dict_from_expr_if_gens(exprs, opt)
#     333 else:
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\polys\polyutils.py:216, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     215             else:
# --> 216                 raise PolynomialError("%s contains an element of "
#     217                                       "the set of generators." % factor)
#     219 monom = tuple(monom)
#
# PolynomialError: RisingFactorial(_t + 1, 1.0) contains an element of the set of generators.
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Inverse Laplace transform to find displacement x(t) in time domain
# ----> 2 x_t = sp.inverse_laplace_transform(X_s, s, t)
#       3 #x_t_simplified = sp.simplify(x_t)
#       5 '''# Display the displacement expression
#       6 print("Displacement (in meters) as a function of time:")
#       7 print(x_t_simplified)'''
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:2097, in inverse_laplace_transform(F, s, t, plane, **hints)
#    2095 if isinstance(F, MatrixBase) and hasattr(F, 'applyfunc'):
#    2096     return F.applyfunc(lambda Fij: inverse_laplace_transform(Fij, s, t, plane, **hints))
# -> 2097 return InverseLaplaceTransform(F, s, t, plane).doit(**hints)
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:171, in IntegralTransform.doit(self, **hints)
#     168 simplify = hints.pop('simplify', True)
#     169 hints['simplify'] = simplify
# --> 171 fn, T = self._try_directly(**hints)
#     173 if T is not None:
#     174     return T
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:135, in IntegralTransform._try_directly(self, **hints)
#     133 if try_directly:
#     134     try:
# --> 135         T = self._compute_transform(self.function,
#     136             self.function_variable, self.transform_variable, **hints)
#     137     except IntegralTransformError:
#     138         T = None
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:2044, in InverseLaplaceTransform._compute_transform(self, F, s, t, **hints)
#    2043 def _compute_transform(self, F, s, t, **hints):
# -> 2044     return _inverse_laplace_transform(F, s, t, self.fundamental_plane, **hints)
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:255, in _noconds_.<locals>.make_wrapper.<locals>.wrapper(noconds, *args, **kwargs)
#     253 @wraps(func)
#     254 def wrapper(*args, noconds=default, **kwargs):
# --> 255     res = func(*args, **kwargs)
#     256     if noconds:
#     257         return res[0]
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:1962, in _inverse_laplace_transform(F, s, t_, plane, simplify)
#    1959     F = F.apart(s)
#    1961 if F.is_Add:
# -> 1962     f = Add(*[_inverse_laplace_transform(X, s, t, plane, simplify)\
#    1963                  for X in F.args])
#    1964     return _simplify(f.subs(t, t_), simplify), True
#    1966 try:
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:1962, in <listcomp>(.0)
#    1959     F = F.apart(s)
#    1961 if F.is_Add:
# -> 1962     f = Add(*[_inverse_laplace_transform(X, s, t, plane, simplify)\
#    1963                  for X in F.args])
#    1964     return _simplify(f.subs(t, t_), simplify), True
#    1966 try:
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:255, in _noconds_.<locals>.make_wrapper.<locals>.wrapper(noconds, *args, **kwargs)
#     253 @wraps(func)
#     254 def wrapper(*args, noconds=default, **kwargs):
# --> 255     res = func(*args, **kwargs)
#     256     if noconds:
#     257         return res[0]
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:1967, in _inverse_laplace_transform(F, s, t_, plane, simplify)
#    1964     return _simplify(f.subs(t, t_), simplify), True
#    1966 try:
# -> 1967     f, cond = inverse_mellin_transform(F, s, exp(-t), (None, S.Infinity),
#    1968                                        needeval=True, noconds=False)
#    1969 except IntegralTransformError:
#    1970     f = None
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:936, in inverse_mellin_transform(F, s, x, strip, **hints)
#     883 def inverse_mellin_transform(F, s, x, strip, **hints):
#     884     r"""
#     885     Compute the inverse Mellin transform of `F(s)` over the fundamental
#     886     strip given by ``strip=(a, b)``.
#    (...)
#     934     hankel_transform, inverse_hankel_transform
#     935     """
# --> 936     return InverseMellinTransform(F, s, x, strip[0], strip[1]).doit(**hints)
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:171, in IntegralTransform.doit(self, **hints)
#     168 simplify = hints.pop('simplify', True)
#     169 hints['simplify'] = simplify
# --> 171 fn, T = self._try_directly(**hints)
#     173 if T is not None:
#     174     return T
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:135, in IntegralTransform._try_directly(self, **hints)
#     133 if try_directly:
#     134     try:
# --> 135         T = self._compute_transform(self.function,
#     136             self.function_variable, self.transform_variable, **hints)
#     137     except IntegralTransformError:
#     138         T = None
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:875, in InverseMellinTransform._compute_transform(self, F, s, x, **hints)
#     872         raise IntegralTransformError('Inverse Mellin', F,
#     873                              'Component %s not recognised.' % f)
#     874 strip = self.fundamental_strip
# --> 875 return _inverse_mellin_transform(F, s, x, strip, **hints)
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:255, in _noconds_.<locals>.make_wrapper.<locals>.wrapper(noconds, *args, **kwargs)
#     253 @wraps(func)
#     254 def wrapper(*args, noconds=default, **kwargs):
# --> 255     res = func(*args, **kwargs)
#     256     if noconds:
#     257         return res[0]
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\integrals\transforms.py:803, in _inverse_mellin_transform(F, s, x_, strip, as_meijerg)
#     801 try:
#     802     from sympy.simplify import hyperexpand
# --> 803     h = hyperexpand(G)
#     804 except NotImplementedError:
#     805     raise IntegralTransformError(
#     806         'Inverse Mellin', F, 'Could not calculate integral')
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\simplify\hyperexpand.py:2494, in hyperexpand(f, allow_hyper, rewrite, place)
#    2492     if not r.has(nan, zoo, oo, -oo):
#    2493         return r
# -> 2494 return f.replace(hyper, do_replace).replace(meijerg, do_meijer)
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\core\basic.py:1581, in Basic.replace(self, query, value, map, simultaneous, exact)
#    1578             expr = v
#    1579     return expr
# -> 1581 rv = walk(self, rec_replace)
#    1582 return (rv, mapping) if map else rv
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\core\basic.py:1566, in Basic.replace.<locals>.walk(rv, F)
#    1564                     if rv == e and e != newargs[i]:
#    1565                         return rv
# -> 1566     rv = F(rv)
#    1567 return rv
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\core\basic.py:1574, in Basic.replace.<locals>.rec_replace(expr)
#    1572 result = _query(expr)
#    1573 if result or result == {}:
# -> 1574     v = _value(expr, result)
#    1575     if v is not None and v != expr:
#    1576         if map:
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\core\basic.py:1503, in Basic.replace.<locals>.<lambda>(expr, result)
#    1501     _value = lambda expr, result: value(*expr.args)
#    1502 elif callable(value):
# -> 1503     _value = lambda expr, result: value(*expr.args)
#    1504 else:
#    1505     raise TypeError(
#    1506         "given a type, replace() expects another "
#    1507         "type or a callable")
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\simplify\hyperexpand.py:2490, in hyperexpand.<locals>.do_meijer(ap, bq, z)
#    2489 def do_meijer(ap, bq, z):
# -> 2490     r = _meijergexpand(G_Function(ap[0], ap[1], bq[0], bq[1]), z,
#    2491                allow_hyper, rewrite=rewrite, place=place)
#    2492     if not r.has(nan, zoo, oo, -oo):
#    2493         return r
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\simplify\hyperexpand.py:2375, in _meijergexpand(func, z0, allow_hyper, rewrite, place)
#    2373 for op in ops:
#    2374     op._poly = Poly(op._poly.subs({z: 1/t, _x: -_x}), _x)
# -> 2375 slater2, cond2 = do_slater(tr(func.bm), tr(func.an), tr(func.bq), tr(func.ap),
#    2376                            t, 1/z0)
#    2378 slater1 = powdenest(slater1.subs(z, z0), polar=True)
#    2379 slater2 = powdenest(slater2.subs(t, 1/z0), polar=True)
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\simplify\hyperexpand.py:2301, in _meijergexpand.<locals>.do_slater(an, bm, ap, bq, z, zfinal)
#    2298     # NOTE even though k "is" +-1, this has to be t/k instead of
#    2299     #      t*k ... we are using polar numbers for consistency!
#    2300     premult = (t/k)**bh
# -> 2301     hyp = _hyperexpand(Hyper_Function(nap, nbq), harg, ops,
#    2302                        t, premult, bh, rewrite=None)
#    2303     res += fac * hyp
#    2304 else:
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\simplify\hyperexpand.py:2042, in _hyperexpand(func, z, ops0, z0, premult, prem, rewrite)
#    2040 # Now try a lerch phi formula
#    2041 if formula is None:
# -> 2042     formula = try_lerchphi(func)
#    2044 if formula is None:
#    2045     debug('  Could not find an origin. ',
#    2046           'Will return answer in terms of '
#    2047           'simpler hypergeometric functions.')
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\simplify\hyperexpand.py:1779, in try_lerchphi(func)
#    1773             denom *= rf(a + t, k)
#    1775 # Now do a partial fraction decomposition.
#    1776 # We assemble two structures: a list monomials of pairs (a, b) representing
#    1777 # a*t**b (b a non-negative integer), and a dict terms, where
#    1778 # terms[a] = [(b, c)] means that there is a term b/(t-a)**c.
# -> 1779 part = apart(numer/denom, t)
#    1780 args = Add.make_args(part)
#    1781 monomials = []
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\utilities\decorator.py:35, in threaded_factory.<locals>.threaded_func(expr, *args, **kwargs)
#      32     return expr.__class__(func(expr.lhs, *args, **kwargs),
#      33                           func(expr.rhs, *args, **kwargs))
#      34 else:
# ---> 35     return func(expr, *args, **kwargs)
#
# File c:\Users\Amay Doshi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\polys\partfrac.py:84, in apart(f, x, full, **options)
#      82 except PolynomialError as msg:
#      83     if f.is_commutative:
# ---> 84         raise PolynomialError(msg)
#      85     # non-commutative
#      86     if f.is_Mul:
#
# PolynomialError: RisingFactorial(_t + 1, 1.0) contains an element of the set of generators.
